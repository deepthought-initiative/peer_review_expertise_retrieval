# %%
import pandas as pd

# %%
notebook_results = pd.read_json('/Users/vicenteamado/Documents/expertise/output/notebook_results.json')

src_results = pd.read_json('/Users/vicenteamado/Documents/expertise/output/src_results.json')

# %%
df_aggregates = pd.json_normalize(notebook_results['aggregates'])
df = pd.concat([notebook_results.drop('aggregates', axis=1), df_aggregates], axis=1)

# %%
df
# Out:
#      method                                       per_proposal  \
# 0  Keywords  {'14499': {'mrr': 0.023809523809523003, 'ndcg'...
# 1    TF-IDF  {'14499': {'mrr': 0.037037037037037, 'ndcg': 0...
# 2       LDA  {'14499': {'mrr': 0.33333333333333304, 'ndcg':...
#
#                                          top_results       mrr      ndcg
# 0  {'14499': [{'reviewer': 'Soulain, Anthony', 's...  0.274722  0.793976
# 1  {'14499': [{'reviewer': 'Rivinius, Th.', 'scor...  0.360754  0.835804
# 2  {'14499': [{'reviewer': 'Rivinius, Th.', 'scor...  0.149328  0.795425
